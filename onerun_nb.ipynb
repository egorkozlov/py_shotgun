# %%
from main_onerun import main

result = main(read_wisdom=True)

globals().update(**result)
# Out:
# Hi!
# read wisdom from file!
# {'sigma_psi': 0.018846757955604386, 'sigma_psi_init': 0.06630677684124549, 'pmeet_21': 0.3135411125790478, 'pmeet_30': 0.9634824070796135, 'pmeet_40': 0.45756357387528424, 'preg_21': 0.011785787325929317, 'preg_28': 0.030162845198796646, 'preg_35': 0.0264523309037068, 'u_shift_mar': 0.25299186827212344, 'util_alp': 0.5996626763425212, 'util_kap': 8.437546362242012, 'util_qbar': 3.937964086760362, 'disutil_marry_sm_mal': 3.8224850978700537, 'disutil_shotgun': 0.5174284742496859, 'abortion_costs': 1.2630390736457893, 'p_abortion_access': 0.8225756487187411, 'u_lost_divorce': 0.8225648170099821, 'mu_psi_init': -0.16123394361285553}
# saved distance is 0.12770904956378548
# using cupy!
# ...
