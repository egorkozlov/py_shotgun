# %%
from main_onerun import main

result = main(read_wisdom=False)

globals().update(**result)
# Out:
# Hi!
# using cupy!
# {'sigma_psi': 0.025092055726001986, 'sigma_psi_init': 0.057524117123893596, 'pmeet_21': 0.37414286769758254, 'pmeet_30': 1.1932756253573578, 'pmeet_40': 1.2, 'preg_21': 0.016846303459086942, 'preg_28': 0.026031363571378165, 'preg_35': 0.028147668865726228, 'u_shift_kid': 0.25811605249933434, 'util_alp': 0.6202419382122233, 'util_kap': 8.328279006156304, 'util_qbar': 19.58211188499201, 'disutil_marry_sm_mal': 11.036758925366986, 'disutil_shotgun': 0.49670652381536956, 'abortion_costs': 2.2609160794229095, 'p_abortion_access': 0.9891922518917426, 'u_lost_divorce': 1.0689656664994374, 'u_shift_couple': -0.16143081649350327, 'high education': True}
# Creation of setup took 1.8, total 1.8, mem 0.98G
# solving for t = 54
# solving for t = 53
# solving for t = 52
# solving for t = 51
# solving for t = 50
# solving for t = 49
# solving for t = 48
# solving for t = 47
# solving for t = 46
# solving for t = 45
# solving for t = 44
# solving for t = 43
# ...
