# %%
from main_onerun import main

result = main(read_wisdom=True)

globals().update(**result)
# Out:
# Hi!
# read wisdom from file!
# {'sigma_psi': 0.017449295610278096, 'sigma_psi_init': 0.061771951899850144, 'pmeet_21': 0.38901014917824395, 'pmeet_30': 1.0, 'pmeet_40': 0.22684416028157747, 'preg_21': 0.010135175059344845, 'preg_28': 0.032346878637142765, 'preg_35': 0.035859798034954704, 'u_shift_mar': 0.26009467501686556, 'util_alp': 0.6155547041501515, 'util_kap': 8.278483302341858, 'util_qbar': 12.157726353872466, 'disutil_marry_sm_mal': 3.936844456585029, 'disutil_shotgun': 0.5385658784554244, 'abortion_costs': 1.1398410672313997, 'p_abortion_access': 0.7873815310228605, 'u_lost_divorce': 0.8334167932473474, 'mu_psi_init': -0.15121444954648872}
# saved distance is 0.014074024503003275
# using cupy!
# ...
