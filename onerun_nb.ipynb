# %%
from main_onerun import main

result = main(read_wisdom=False)

globals().update(**result)
# Out:
# Hi!
# using cupy!
# {'sigma_psi': 0.024447077354810887, 'sigma_psi_init': 0.026287447678799637, 'pmeet_21': 0.16181842291258391, 'pmeet_30': 0.4844756482942769, 'pmeet_40': 0.6278134903824727, 'preg_21': 0.008825649168577587, 'preg_28': 0.029699717484135257, 'preg_35': 0.01697979902262614, 'u_shift_kid': 0.29959929396641477, 'util_alp': 0.7103357592468402, 'util_kap': 7.232876352397827, 'util_qbar': 40.0, 'disutil_marry_sm_mal': 2.109356551078698, 'disutil_shotgun': 0.812424825412403, 'abortion_costs': 1.0847666887625578, 'p_abortion_access': 1.0, 'u_lost_divorce': 0.930254920866958, 'u_shift_couple': -0.055377440502576314, 'high education': True}
# Creation of setup took 2.09, total 2.09, mem 0.9G
# solving for t = 54
# solving for t = 53
# solving for t = 52
# solving for t = 51
# solving for t = 50
# solving for t = 49
# solving for t = 48
# solving for t = 47
# solving for t = 46
# solving for t = 45
# solving for t = 44
# solving for t = 43
# ...
