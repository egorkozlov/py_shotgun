# %% [markdown]
# # Fit Plots
# This thing is used to compare several calibrations
#
# ## General Imports

# %%
from main_generate_moments import adj_list, run
adict = adj_list(return_dict=True)
# Out:
# using cupy!

# %% [markdown]
# ## Baseline Fit
# ### College

# %%
mom_col_bl, fp_col_bl = run('baseline',{},'col',noplot=True,resume=True)
fp_col_bl.plot()
# Out:
# doing col baseline
# file col baseline.pkl already exists
# done, doing fit plots
# divorced if k then m and one marriage: base 0.09503409054626544, compare 0.1480121
# divorced by years after marriage if kids first, 10: base 0.12979100111395744, compare 0.20118
# divorced if m then k and one marriage: base 0.03514631447865653, compare 0.0536316
# divorced by years after marriage if marriage first, 10: base 0.04289203914518955, compare 0.0602147
# /projects/p30190/py_shotgun/fit_plot.py:246: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(gs[0,0])
# ('KF', array([0.01637572, 0.04087535, 0.06132586, 0.07881877, 0.10098718,
#        0.11469567, 0.12060834, 0.12448041, 0.12826674, 0.129791  ]))
# ('MF', array([0.        , 0.00721122, 0.0129673 , 0.01841019, 0.02351964,
#        0.02752082, 0.03156587, 0.03513173, 0.03958052, 0.04289204]))
# 'value function: couple, no children, no assets'
# failed to plot ref

# %% [markdown]
# ### High School

# %%
mom_hs_bl, fp_hs_bl = run('baseline',{},'hs',noplot=True,resume=True)
fp_col_bl.plot()
# Out:
# doing hs baseline
# file hs baseline.pkl already exists
# done, doing fit plots
# divorced if k then m and one marriage: base 0.16716412007345277, compare 0.1727448
# divorced by years after marriage if kids first, 10: base 0.23992653404029837, compare 0.2115082
# divorced if m then k and one marriage: base 0.13551492134533966, compare 0.1394705
# divorced by years after marriage if marriage first, 10: base 0.15761744594497584, compare 0.1443613
# /projects/p30190/py_shotgun/fit_plot.py:246: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(gs[0,0])
# ('KF', array([0.01637572, 0.04087535, 0.06132586, 0.07881877, 0.10098718,
#        0.11469567, 0.12060834, 0.12448041, 0.12826674, 0.129791  ]))
# ('MF', array([0.        , 0.00721122, 0.0129673 , 0.01841019, 0.02351964,
#        0.02752082, 0.03156587, 0.03513173, 0.03958052, 0.04289204]))
# 'value function: couple, no children, no assets'
# failed to plot ref

# %% [markdown]
# ## No Social Stigma and Perfect Fertility Control
#
# ### College

# %%
adj = adict['no social stigma']

mom_col_bl, fp_col_bl = run('no stigma',adj,'col',noplot=True,resume=True)
fp_col_bl.plot_cumulative()
fp_col_bl.plot_kfmf()
fp_col_bl.plot_welfare()
# Out:
# doing col no stigma
# computing col no stigma.pkl
# Distance 14.247305803890907, time 82.66
# file col no stigma.pkl saved
# done, doing fit plots
# divorced if k then m and one marriage: base 0.06705023176773792, compare 0.09503409054626544
# divorced by years after marriage if kids first, 10: base 0.10247776169529814, compare 0.12979100111395744
# divorced if m then k and one marriage: base 0.03427903252485197, compare 0.03514631447865653
# divorced by years after marriage if marriage first, 10: base 0.04155831678230829, compare 0.04289203914518955
# /projects/p30190/py_shotgun/fit_plot.py:246: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(gs[0,0])
# ('KF', array([0.00480026, 0.01357012, 0.02533765, 0.03903502, 0.0589604 ,
#        0.07576876, 0.08271345, 0.08864373, 0.0960506 , 0.10247776]))
# ('MF', array([0.        , 0.00723832, 0.01304331, 0.01821472, 0.02296261,
#        0.02663347, 0.03059205, 0.03408893, 0.03814558, 0.04155832]))

# %%
adj = adict['abortions and no stigma']
mom_col_bl, fp_col_bl = run('no stigma + fertility control',adj,'col',noplot=True,resume=False)
fp_col_bl.plot_cumulative()
fp_col_bl.plot_kfmf()
fp_col_bl.plot_welfare()
# Out:
# doing col no stigma + fertility control
# computing col no stigma + fertility control.pkl
# Distance 10.634402471305641, time 75.74
# file col no stigma + fertility control.pkl saved
# done, doing fit plots
# divorced if k then m and one marriage: base 0.02986942032685711, compare 0.09503409054626544
# divorced by years after marriage if kids first, 10: base 0.04856427865123518, compare 0.12979100111395744
# divorced if m then k and one marriage: base 0.0336707075383207, compare 0.03514631447865653
# divorced by years after marriage if marriage first, 10: base 0.04144263846916408, compare 0.04289203914518955
# /projects/p30190/py_shotgun/fit_plot.py:246: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(gs[0,0])
# ('KF', array([0.00181924, 0.00605339, 0.01124   , 0.01693419, 0.0282515 ,
#        0.0356519 , 0.04026027, 0.04346715, 0.04848228, 0.04856428]))
# ('MF', array([0.        , 0.00741302, 0.01288031, 0.0181736 , 0.02272283,
#        0.02674062, 0.03066568, 0.03422741, 0.03823013, 0.04144264]))

# %% [markdown]
# ### High School

# %%
adj = adict['no social stigma']

mom_col_bl, fp_col_bl = run('no stigma',adj,'hs',noplot=True,resume=False)
fp_col_bl.plot_cumulative()
fp_col_bl.plot_kfmf()
fp_col_bl.plot_welfare()

# %%
adj = adict['abortions and no stigma']

mom_col_bl, fp_col_bl = run('no stigma + fertility control',adj,'hs',noplot=True,resume=False)
fp_col_bl.plot_cumulative()
fp_col_bl.plot_kfmf()
fp_col_bl.plot_welfare()

# %% [markdown]
# ## Child Support
#
# ### College

# %%
adj = adict['full child support']

mom_col_bl, fp_col_bl = run('full child support',adj,'col',noplot=True,resume=False)

# Child support does not get people married
fp_col_bl.plot_cumulative()
fp_col_bl.plot_kfmf()
fp_col_bl.plot_welfare()

# %% [markdown]
# ### High School

# %%
adj = adict['full child support']

mom_col_bl, fp_col_bl = run('full child support',adj,'hs',noplot=True,resume=False)

# Nor for high school
fp_col_bl.plot_cumulative()
fp_col_bl.plot_kfmf()

# %%
adj = adict['full child support']

mom_col_bl, fp_col_bl = run('full child support',adj,'col',noplot=True,resume=False)

# Nor for high school
fp_col_bl.plot_cumulative()
fp_col_bl.plot_kfmf()
fp_col_bl.plot_welfare()
