# %%
# This is the notebook for plots

from estimates import get_point

x_col, t_col = get_point(True,read_wisdom=False)
x_hs, t_hs = get_point(False,read_wisdom=False)

x_all = {'col_'+f : x_col[f] for f in x_col}
x_all.update( {'hs_'+f : x_hs[f] for f in x_hs} )

# %%
print('\n\nTable with estimates\n\n')

print(r'$(\phi_0,\alpha)$ & ' + 'Fertility preferences & $({col_u_shift_mar:02.2f},{col_util_alp:02.2f})$ & $({hs_u_shift_mar:02.2f}^*,{hs_util_alp:02.2f}^*)$'.format(**x_all) + r' \\')
print(r'$q$ & ' + 'Required childcare costs & ${col_util_qbar:02.2f}$ & ${hs_util_qbar:02.2f}$'.format(**x_all) + r' \\')
print(r'$\sigma_\psi$ & ' + 'Match quality shock size & ${col_sigma_psi:02.2f}$ & ${hs_sigma_psi:02.2f}^*$'.format(**x_all) + r' \\')
print(r'$(\mu_{\psi,0},\sigma_{\psi,0})$ & ' + 'Match quality initial distribution & $({col_sigma_psi_init:02.2f},{col_mu_psi_init:02.2f})$ & $({hs_sigma_psi_init:02.2f}^*,{hs_mu_psi_init:02.2f}^*)$'.format(**x_all) + r' \\')
print(r'$(p^{\text{meet}}_{21},p^{\text{meet}}_{30},p^{\text{meet}}_{40})$ & ' + 'Meeting probabilities (quadratic) & $({col_pmeet_21:02.2f},{col_pmeet_30:02.2f},{col_pmeet_40:02.2f})$ & $({hs_pmeet_21:02.2f},{hs_pmeet_30:02.2f},{hs_pmeet_40:02.2f})$'.format(**x_all) + r' \\')
print(r'$(p^{\text{preg}}_{21},p^{\text{meet}}_{28},p^{\text{meet}}_{35})$ & ' +  'Unplanned preg. probabilities & $({col_preg_21:02.3f},{col_preg_28:02.3f},{col_preg_35:02.3f})$ & $({hs_preg_21:02.2f},{hs_preg_28:02.2f},{hs_preg_35:02.2f})$'.format(**x_all) + r' \\')
print(r'$(p^a,\phi_a)$ & ' + 'Abortion access and costs & $({col_p_abortion_access:02.2f},{col_abortion_costs:02.1f})$ & $({hs_p_abortion_access:02.2f},{hs_abortion_costs:02.2f})$'.format(**x_all) + r' \\')
print(r'$\phi_d$ & ' + 'Utility costs of divorce & ${col_u_lost_divorce:02.1f}$ & ${hs_u_lost_divorce:02.1f}$'.format(**x_all) + r' \\')
print(r'$\phi_s$ & ' +'Shotgun marriage stigma & ${col_disutil_shotgun:02.1f}$ & ${hs_disutil_shotgun:02.1f}$'.format(**x_all) + r' \\')
print(r'$\phi_r$ & ' +'Utility loss from stepchildren & ${col_disutil_marry_sm_mal:02.1f}$ & ${hs_disutil_marry_sm_mal:02.1f}$'.format(**x_all) + r' \\')
# Out:
# Table with estimates
#
#
# $(\phi_0,\alpha)$ & Fertility preferences & $(0.30,0.45)$ & $(0.30^*,0.45^*)$ \\
# $q$ & Required childcare costs & $34.39$ & $1.23$ \\
# $\sigma_\psi$ & Match quality shock size & $0.67$ & $0.67^*$ \\
# $(\mu_{\psi,0},\sigma_{\psi,0})$ & Match quality initial distribution & $(1.28,-1.44)$ & $(1.28^*,-1.44^*)$ \\
# $(p^{\text{meet}}_{21},p^{\text{meet}}_{30},p^{\text{meet}}_{40})$ & Meeting probabilities (quadratic) & $(0.33,0.86,0.50)$ & $(0.81,0.30,1.00)$ \\
# $(p^{\text{preg}}_{21},p^{\text{meet}}_{28},p^{\text{meet}}_{35})$ & Unplanned preg. probabilities & $(0.016,0.035,0.033)$ & $(0.15,0.06,0.50)$ \\
# $(p^a,\phi_a)$ & Abortion access and costs & $(0.86,6.3)$ & $(1.00,0.02)$ \\
# $\phi_d$ & Utility costs of divorce & $14.9$ & $10.1$ \\
# $\phi_s$ & Shotgun marriage stigma & $5.3$ & $6.3$ \\
# $\phi_r$ & Utility loss from stepchildren & $20.9$ & $20.6$ \\

# %%
print('\n\n\n Table with fit \n\n\n')
from tiktak import filer
mom_col = filer('col baseline.pkl',0,0)
mom_hs = filer('hs baseline.pkl',0,0)
from targets import all_targets
tar_col = all_targets(t_col)
tar_hs = all_targets(t_hs)



def getkey(key):
    return [100*mom_col[key],100*tar_col[key][0],100*mom_hs[key],100*tar_hs[key][0]]
def getcell(key):
    return '{:02.1f} & {:02.1f} & {:02.1f} & {:02.1f}'.format(*getkey(key))

def getrow(desc,key):
    return r'{\footnotesize ' + desc + '} & '+ getcell(key) + r' \\'

print(getrow(r' \% with more than one marriage at 40','more than one mar at 40'))
print(getrow(r'\% in labor force at 30 if married and kids','in labor force at 30 if kids'))
print(getrow(r'mean \% of child expenditures in total earnings','mean x share'))
print(getrow(r'\% unplanned pregnancies aborted','unplanned pregnancies aborted'))
print(getrow(r'abortions in 30s as \% of abortions in 20s','abortion 30s over 20s'))
# Out:
#  Table with fit
#
#
#
# {\footnotesize  \% with more than one marriage at 40} & 6.8 & 11.9 & 9.6 & 17.1 \\
# {\footnotesize \% in labor force at 30 if married and kids} & 74.2 & 74.0 & 53.6 & 54.7 \\
# {\footnotesize mean \% of child expenditures in total earnings} & 40.6 & 40.0 & 39.3 & 40.0 \\
# {\footnotesize \% unplanned pregnancies aborted} & 39.9 & 40.0 & 37.3 & 40.0 \\
# {\footnotesize abortions in 30s as \% of abortions in 20s} & 38.5 & 38.5 & 39.5 & 38.5 \\

# %%
# fit plots: college

from fit_plot import FitPlots
fp = FitPlots(targ_mode=t_col,
               compare=None,
               base='college baseline.pkl',
               compare_name='data',
               base_name='college baseline',
               moments_aux=None)
# Out:
# using cpu!
# divorced if k then m and one marriage: base 0.09821428571428571, compare 0.1480121
# divorced by years after marriage if kids first, 10: base 0.18327402135231316, compare 0.20118
# divorced if m then k and one marriage: base 0.047027139009736894, compare 0.0536316
# divorced by years after marriage if marriage first, 10: base 0.06524166533737438, compare 0.0602147
# /Users/egorkozlov/GoogleDrive/Research/py_shotgun/fit_plot.py:284: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(gs[0,0])
# ('KF', array([0.00537057, 0.02207506, 0.05310734, 0.07674144, 0.09447853,
#        0.11296534, 0.13451087, 0.15294118, 0.1664    , 0.18327402]))
# ('MF', array([0.        , 0.00054348, 0.00497435, 0.01012439, 0.01915071,
#        0.02806681, 0.03922378, 0.04726757, 0.05621654, 0.06524167]))
# failed to plot single moms (new)
# failed to plot welfare
# failed to plot ref

# %%
from shutil import copyfile
fnames = ['fit_single_nonmothers_div.pdf',
         'fit_single_mothers_nm.pdf',
         'fit_single_mothers_div.pdf',
         'relshares.pdf',
         'popshares.pdf',
         'fit_single_nonmothers_nm.pdf',
         'div_kfmf.pdf',
         'kids_by_duration.pdf']


for fname in fnames:
    copyfile(fname,'pics/col/'+fname)

# %%
# fit plots: hs

from fit_plot import FitPlots
fp = FitPlots(targ_mode=t_hs,
               compare=None,
               base='hs baseline.pkl',
               compare_name='data',
               base_name='high school baseline',
               moments_aux=None)

for fname in fnames:
    copyfile(fname,'pics/hs/'+fname)
# Out:
# divorced if k then m and one marriage: base 0.1478782576946621, compare 0.1727448
# divorced by years after marriage if kids first, 10: base 0.2167765885022399, compare 0.2115082
# divorced if m then k and one marriage: base 0.1367945694994923, compare 0.1394705
# divorced by years after marriage if marriage first, 10: base 0.15903129281753428, compare 0.1443613
# /Users/egorkozlov/GoogleDrive/Research/py_shotgun/fit_plot.py:284: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(gs[0,0])
# ('KF', array([0.02096767, 0.05241918, 0.08381454, 0.11399984, 0.14031542,
#        0.15818035, 0.17587964, 0.19110588, 0.20528379, 0.21677659]))
# ('MF', array([0.        , 0.01615499, 0.03659878, 0.05941952, 0.08276597,
#        0.10263949, 0.11770968, 0.13216345, 0.14751815, 0.15903129]))
# failed to plot single moms (new)
# failed to plot welfare
# failed to plot ref

# %%
# part 6.1 plots:

run_this = False

if run_this:

    from residuals import mdl_resid

    out, mdl, agents, res, mom = mdl_resid(x=x_col,targets=tar_col,
                                          return_format=['distance','models','agents','scaled residuals','moments'],
                                          load_from='mdl.pkl',
                                          #verbose=True,draw=True,cs_moments=False,
                                          #moments_save_name = this_name,
                                          moments_repeat=1)


    mdl[0].mar_graphs()

    fnames = ['change_upp.pdf','tholds_upp.pdf']
    for fname in fnames:
        copyfile(fname,'pics/'+fname)

# %%
# part 6.2 col:


from cf_table import produce_cf_table
produce_cf_table('col')
# Out:
# \textbf{Experiment} & \textbf{BL} & \textbf{NS} & \textbf{FC} & \textbf{NR} & \textbf{FD} & \textbf{ND} \\
# \textit{divorced in 10 years, kids-first} & 21.1 & 14.5 & 16.7 & 13.9 & 56.6 & 0.0 \\
# \textit{divorced in 10 years, marriage-first} & 6.2 & 5.8 & 5.9 & 11.9 & 1.9 & 0.0 \\
# \textit{kids-first at 30} & 11.5 & 8.1 & 8.5 & 12.6 & 36.4 & 7.6 \\
# \textit{unplanned pregnancies aborted} & 39.9 & 48.4 & 76.6 & 1.0 & 35.6 & 41.8 \\
# \textit{single mothers at 35} & 13.2 & 13.8 & 6.9 & 14.9 & 19.6 & 13.6 \\

# %%
# part 6.2 hs:

produce_cf_table('hs')
# Out:
# \textbf{Experiment} & \textbf{BL} & \textbf{NS} & \textbf{FC} & \textbf{NR} & \textbf{FD} & \textbf{ND} \\
# \textit{divorced in 10 years, kids-first} & 21.7 & 13.7 & 21.6 & 22.0 & 37.8 & 0.0 \\
# \textit{divorced in 10 years, marriage-first} & 15.9 & 2.0 & 15.8 & 20.2 & 7.3 & 0.0 \\
# \textit{kids-first at 30} & 36.5 & 49.5 & 36.5 & 47.7 & 63.3 & 35.7 \\
# \textit{unplanned pregnancies aborted} & 37.3 & 87.3 & 37.7 & 0.2 & 34.0 & 10.4 \\
# \textit{single mothers at 35} & 42.8 & 49.2 & 42.7 & 32.3 & 50.3 & 44.4 \\

# %%
# part 6.3:

run_col = False
run_hs = False
from causal_effects import get_causal_table
from dill import load


if run_col:
    #mdl = load(open('mdl.pkl','rb+'))
    out, mdls = mdl_resid(x=x_col,targets=tar_col,return_format=['distance','models'])
    mdl = mdls[0]
    get_causal_table(mdl)
   
if run_hs:
    #mdl = load(open('mdl_hs.pkl','rb+'))
    out, mdls = mdl_resid(x=x_hs,targets=tar_hs,return_format=['distance','models'])
    mdl = mdls[0]
    get_causal_table(mdl)

# %%
# part 6.4

import numpy as np
from matplotlib import pyplot as plt

diff = False

em_25 = r'\textit{\% ever married at 25} '
em_30 = r'\textit{\% ever married at 30} '
em_35 = r'\textit{\% ever married at 35} '
mk_25 = r'\textit{\% married and with kids at 25} '
mk_30 = r'\textit{\% married and with kids at 30} '
mk_35 = r'\textit{\% married and with kids at 35} '

ed_30 = r'\textit{\% ever divorced at 30} '
ed_40 = r'\textit{\% ever divorced at 40} '
ed_50 = r'\textit{\% ever divorced at 50} '
sm_25 = r'\textit{\% single mothers at 25} '
sm_30 = r'\textit{\% single mothers at 30} '
sm_35 = r'\textit{\% single mothers at 35} '
dm_10 = r'\textit{\% divorced 10 years after if MF} '




for educ, name in zip(['hs','col'],['high school graduates','college graduates']):

    mom_bl = filer('{} baseline.pkl'.format(educ),0,0)
    mom_ne = filer('{} no unplanned pregnancy unanticipated.pkl'.format(educ),0,0)
    mom_na = filer('{} no unplanned pregnancy.pkl'.format(educ),0,0)

    tval = np.arange(23,36)  
    em_bl, em_ne, em_na = (np.array([100*mom['ever married at {}'.format(t)] for t in tval]) 
                           for mom in (mom_bl, mom_ne, mom_na))

    yamval = np.arange(1,11)  

    wk_bl, wk_ne, wk_na = (np.array([100*mom['ever kids by years after marriage, {}'.format(y)] for y in yamval]) 
                           for mom in (mom_bl, mom_ne, mom_na))



    fig, ax = plt.subplots()
    if diff:
        plt.hlines(0,22,35,linestyles='dotted',colors='b')
        plt.plot(tval,em_ne-em_bl,'d--r',label='never experienced')
        plt.plot(tval,em_na-em_bl,'x-k',label='never anticipated')
        plt.ylabel('share - baseline share (percentage points)')
    else:
        plt.plot(tval,em_bl,'o-k',label='baseline')
        plt.plot(tval,em_ne,'d--r',label='never experienced')
        plt.plot(tval,em_na,'x-b',label='never anticipated')
        plt.ylabel('share (%)')
        
    ax.grid(True)
    xticks = [i for i in range(22,36)]
    ax.set_xticks(xticks)
    plt.legend()
    plt.title(name+': '+'ever married') 
    plt.xlabel('age')
    
    plt.savefig('evermar.pdf')

    fig, ax = plt.subplots()
    if diff:
        plt.hlines(0,0,10,linestyles='dashed',colors='b')
        plt.plot(yamval,wk_ne-wk_bl,'d--r',label='never experienced')
        plt.plot(yamval,wk_na-wk_bl,'x-k',label='never anticipated')
        plt.ylabel('share - baseline share (percentage points)')
    else:
        plt.plot(yamval,wk_bl,'o-k',label='baseline')
        plt.plot(yamval,wk_ne,'d--r',label='never experienced')
        plt.plot(yamval,wk_na,'x-b',label='never anticipated')
        plt.ylabel('share (%)')

    ax.grid(True)
    xticks = yamval #[i for i in range(22,36)]
    ax.set_xticks(xticks)
    plt.legend()
    plt.title(name+':\n'+'% with kids by years after marriage (if married)') 
    plt.xlabel('years after marriage')
    plt.savefig('kids_by_duration.pdf')
    
    for mom in (mom_bl, mom_ne, mom_na):
        em_25 += r' & ' + '{:02.1f}'.format(100*mom['ever married at 25'])
        em_30 += r' & ' + '{:02.1f}'.format(100*mom['ever married at 30'])
        em_35 += r' & ' + '{:02.1f}'.format(100*mom['ever married at 35'])
        
        mk_25 += r' & ' + '{:02.1f}'.format(100*(mom['m then k in population at 25'] + \
                                                 mom['k then m in population at 25']))
        mk_30 += r' & ' + '{:02.1f}'.format(100*(mom['m then k in population at 30'] + \
                                                 mom['k then m in population at 30']))
        mk_35 += r' & ' + '{:02.1f}'.format(100*(mom['m then k in population at 35'] + \
                                                 mom['k then m in population at 35']))
        
        ed_30 += r' & ' + '{:02.1f}'.format(100*mom['ever divorced at 30'])
        ed_40 += r' & ' + '{:02.1f}'.format(100*mom['ever divorced at 40'])
        ed_50 += r' & ' + '{:02.1f}'.format(100*mom['ever divorced at 50'])
        
        sm_25 += r' & ' + '{:02.1f}'.format(100*mom['single mothers in total at 25'])
        sm_30 += r' & ' + '{:02.1f}'.format(100*mom['single mothers in total at 30'])
        sm_35 += r' & ' + '{:02.1f}'.format(100*mom['single mothers in total at 35'])
        
        dm_10 += r' & ' + '{:02.1f}'.format(100*mom['divorced by years after marriage if marriage first, 10'])
        
        
        fnames = ['evermar.pdf','kids_by_duration.pdf']
        for fname in fnames:
            copyfile(fname,'pics/anticipation/{}/'.format(educ)+fname)
        
        
        
    
print(em_25)
print(em_30)
print(em_35)
print(mk_25)
print(mk_30)
print(mk_35)
print(ed_30)
print(ed_40)
print(ed_50)
print(sm_25)
print(sm_30)
print(sm_35)
print(dm_10)
# Out:
# \textit{\% ever married at 25}  & 39.5 & 37.6 & 36.2 & 25.9 & 25.4 & 23.5
# \textit{\% ever married at 30}  & 56.4 & 54.9 & 50.5 & 59.7 & 59.2 & 55.0
# \textit{\% ever married at 35}  & 68.7 & 67.2 & 58.8 & 78.9 & 79.9 & 76.1
# \textit{\% married and with kids at 25}  & 16.6 & 11.7 & 3.8 & 6.3 & 5.3 & 4.4
# \textit{\% married and with kids at 30}  & 33.5 & 29.2 & 10.5 & 32.2 & 30.1 & 27.0
# \textit{\% married and with kids at 35}  & 45.5 & 39.1 & 19.5 & 55.9 & 55.0 & 51.4
# \textit{\% ever divorced at 30}  & 8.0 & 7.1 & 6.8 & 4.4 & 4.1 & 3.5
# \textit{\% ever divorced at 40}  & 21.2 & 18.7 & 21.2 & 17.0 & 16.8 & 15.9
# \textit{\% ever divorced at 50}  & 35.3 & 35.5 & 31.9 & 32.3 & 32.7 & 31.4
# \textit{\% single mothers at 25}  & 22.4 & 22.0 & 22.4 & 2.7 & 1.9 & 1.9
# \textit{\% single mothers at 30}  & 24.0 & 22.1 & 21.6 & 5.1 & 2.1 & 1.9
# \textit{\% single mothers at 35}  & 29.8 & 23.5 & 21.3 & 8.4 & 3.9 & 3.4
# \textit{\% divorced 10 years after if MF}  & 15.9 & 15.8 & 2.1 & 6.2 & 6.1 & 5.3

# %%
# part 6.4 welfare gains

for educ in ['hs','col']:
    from fit_plot import FitPlots
    fp = FitPlots(targ_mode=t_col if (educ=='col') else t_hs,
                   compare='{} baseline.pkl'.format(educ),
                   base='{} no unplanned pregnancy.pkl'.format(educ),
                   compare_name='data',
                   base_name='{} baseline'.format(educ),
                   moments_aux=None,noplot=True)
    fp.plot_welfare()
# Out:
# divorced if k then m and one marriage: base 0.07857663151001917, compare 0.1478782576946621
# divorced by years after marriage if kids first, 10: base 0.0910610101023578, compare 0.2167765885022399
# divorced if m then k and one marriage: base 0.025968545433168167, compare 0.1367945694994923
# divorced by years after marriage if marriage first, 10: base 0.020656351871229352, compare 0.15903129281753428
#
# extra assets in base to reach 0 in compare
#
# v0 is larger in 280 cases
# v0 is smaller in 0 cases
#
# extra assets in compare to reach 0 in base
#
# v0 is larger in 0 cases
# v0 is smaller in 280 cases
#
# extra assets in base to reach 0 in compare
#
# v0 is larger in 200 cases
# v0 is smaller in 0 cases
#
# extra assets in compare to reach 0 in base
#
# v0 is larger in 0 cases
# v0 is smaller in 200 cases
# [500. 500. 500. 500. 500.]
# [343.75373892 382.52415723 432.34935668 482.66014162 500.
#  500.         500.        ]
#
# extra assets in base to reach 0 in compare
#
# v0 is larger in 680 cases
# v0 is smaller in 0 cases
#
# extra assets in compare to reach 0 in base
#
# v0 is larger in 0 cases
# v0 is smaller in 680 cases
# divorced if k then m and one marriage: base 0.0363878792847448, compare 0.12206262482238266
# divorced by years after marriage if kids first, 10: base 0.06843085975809086, compare 0.21147730438875728
# divorced if m then k and one marriage: base 0.03552678387974576, compare 0.04413706828086659
# divorced by years after marriage if marriage first, 10: base 0.05316684876262776, compare 0.061562704456673556
#
# extra assets in base to reach 0 in compare
#
# v0 is larger in 280 cases
# v0 is smaller in 0 cases
#
# extra assets in compare to reach 0 in base
#
# v0 is larger in 0 cases
# v0 is smaller in 280 cases
#
# extra assets in base to reach 0 in compare
#
# v0 is larger in 200 cases
# v0 is smaller in 0 cases
#
# extra assets in compare to reach 0 in base
#
# v0 is larger in 0 cases
# v0 is smaller in 200 cases
# [ 90.61224536 149.86618211 222.15396439 311.35027548 437.44124517]
# [ 90.39012507 153.62581484 242.34654148 344.96086942 468.83357197
#  500.         500.        ]
#
# extra assets in base to reach 0 in compare
#
# v0 is larger in 680 cases
# v0 is smaller in 0 cases
#
# extra assets in compare to reach 0 in base
#
# v0 is larger in 0 cases
# v0 is smaller in 680 cases

# %%
# part 6.5 (education gradient)

names_select = [('Col','educ comparison: college'),
                ('HS','educ comparison: high school'), 
                ('I','educ comparison: trend only'),
                ('M','educ comparison: pmeets'), 
                ('P','educ comparison: ppregs'),
                ('D','educ comparison: div costs'),
                ('R','educ comparison: remar'), 
                ('S','educ comparison: stigma'),
                ('A','educ comparison: abortions'),
                ('Q','educ comparison: qbar')]

tags = ''
div_kfs = 'divorced if kids first'
div_mfs = 'divorced if marriage first'
div_rats = 'divorced ratio KF/MF'
kf_rels = 'relative KF at 35'
kf_pops = 'population KF at 35'
mf_pops = 'population MF at 35'

for tag, name in names_select:
    mom = filer(name + '.pkl',0,0,repeat=False)
    div_10_kf = mom['divorced by years after marriage if kids first, 10']
    div_10_mf = mom['divorced by years after marriage if marriage first, 10']
    share_kf_35 = mom['k then m in sample at 35']
    pop_kf_35 = mom['k then m in population at 35']
    pop_mf_35 = mom['m then k in population at 35']
    div_cs_kf = mom['divorced if k then m and one marriage']
    div_cs_mf = mom['divorced if m then k and one marriage']
    div_kfs += ' & {:02.1f}'.format(100*div_10_kf)
    div_mfs += ' & {:02.1f}'.format(100*div_10_mf)
    div_rats += ' & {:02.1f}'.format(div_10_kf/div_10_mf)
    kf_rels += ' & {:02.1f}'.format(100*share_kf_35)
    kf_pops += ' & {:02.1f}'.format(100*pop_kf_35)
    mf_pops += ' & {:02.1f}'.format(100*pop_mf_35)
    tags += (' & ' + tag)
    
tags += r' \\'
div_kfs += r' \\'
div_mfs += r' \\'
div_rats += r' \\'
kf_rels += r' \\'

    
print(tags)
print(div_kfs)
print(div_mfs)
print(div_rats)
#print(kf_rels)
print(kf_pops)
print(mf_pops)
# Out:
#  & Col & HS & I & M & P & D & R & S & A & Q \\
# divorced if kids first & 21.1 & 21.7 & 10.5 & 24.0 & 18.6 & 30.1 & 20.5 & 22.5 & 16.7 & 20.7 \\
# divorced if marriage first & 6.2 & 15.9 & 3.0 & 4.9 & 10.9 & 7.5 & 6.5 & 6.3 & 5.9 & 7.0 \\
# divorced ratio KF/MF & 3.4 & 1.4 & 3.5 & 4.9 & 1.7 & 4.0 & 3.2 & 3.6 & 2.8 & 3.0 \\
# population KF at 35 & 5.2 & 17.8 & 9.0 & 3.5 & 15.0 & 5.8 & 5.2 & 5.8 & 3.9 & 5.5
# population MF at 35 & 50.7 & 27.7 & 22.3 & 35.2 & 55.8 & 41.4 & 51.6 & 51.0 & 51.3 & 53.3

# %%
# part 6.6 childbearing => divorce risks and back

from child_effects import get_child_effects_graphs
from residuals import mdl_resid

run_col = False
run_hs = False
from dill import load


if run_col:
    mdl = load(open('mdl.pkl','rb+'))
    #out, mdls, agents = mdl_resid(x=x_col,targets=tar_col,load='mdl.pkl',return_format=['distance','models','agents'])
    #out, mdls, agents = mdl_resid(x=x_col,targets=tar_col,return_format=['distance','models','agents'])
    #mdl = mdls[0]
    #agents.sim_graphs()
    get_child_effects_graphs(mdl)
   
if run_hs:
    mdl = load(open('mdl_hs.pkl','rb+'))
    #out, mdls, agents = mdl_resid(x=x_hs,targets=tar_hs,return_format=['distance','models','agents'])
    #mdl = mdls[0]
    #agents.sim_graphs()
    get_child_effects_graphs(mdl)
# Out:
# /Users/egorkozlov/GoogleDrive/Research/py_shotgun/simulations.py:611: RuntimeWarning: invalid value encountered in long_scalars
#   self.share_aborted[t] = 100*n_abortions / (n_abortions + n_kept)
# Simulations, iteration took 2.06, total -61474.66, mem 0.45G
# Simulations, iteration took 1.48, total -61473.17, mem 0.46G
# Simulations, iteration took 1.25, total -61471.92, mem 0.46G
# Simulations, iteration took 1.37, total -61470.56, mem 0.46G
# Simulations, iteration took 1.13, total -61469.43, mem 0.48G
# Simulations, iteration took 1.11, total -61468.32, mem 0.5G
# Simulations, iteration took 0.9, total -61467.42, mem 0.53G
# Simulations, iteration took 0.83, total -61466.58, mem 0.55G
# Simulations, iteration took 0.76, total -61465.83, mem 0.58G
# Simulations, iteration took 0.79, total -61465.04, mem 0.62G
# Simulations, iteration took 0.67, total -61464.37, mem 0.65G
# Simulations, iteration took 0.64, total -61463.73, mem 0.68G
# Simulations, iteration took 0.6, total -61463.13, mem 0.71G
# Simulations, iteration took 0.58, total -61462.55, mem 0.74G
# Simulations, iteration took 0.69, total -61461.86, mem 0.76G
# Simulations, iteration took 0.64, total -61461.22, mem 0.79G
# Simulations, iteration took 0.55, total -61460.67, mem 0.81G
# Simulations, iteration took 0.62, total -61460.04, mem 0.84G
# Simulations, iteration took 0.63, total -61459.41, mem 0.88G
# Simulations, iteration took 0.52, total -61458.89, mem 0.91G
# Simulations, iteration took 0.56, total -61458.33, mem 0.93G
# Simulations, iteration took 0.6, total -61457.73, mem 0.95G
# Simulations, iteration took 0.59, total -61457.14, mem 0.99G
# Simulations, iteration took 0.57, total -61456.57, mem 1.02G
# Simulations, iteration took 0.61, total -61455.96, mem 1.06G
# Simulations, iteration took 0.62, total -61455.34, mem 1.09G
# Simulations, iteration took 0.62, total -61454.72, mem 1.12G
# Simulations, iteration took 0.61, total -61454.11, mem 1.15G
# Simulations, iteration took 0.65, total -61453.46, mem 1.18G
# Simulations, iteration took 0.7, total -61452.76, mem 1.21G
# Simulations, iteration took 0.92, total -61451.84, mem 1.24G
# Simulations, iteration took 0.73, total -61451.11, mem 1.27G
# Simulations, iteration took 0.71, total -61450.4, mem 1.27G
# Simulations, iteration took 0.79, total -61449.61, mem 1.29G
# Simulations, iteration took 0.73, total -61448.88, mem 1.32G
# Simulations, iteration took 0.63, total -61448.24, mem 1.15G
# Simulations, iteration took 0.6, total -61447.64, mem 1.17G
# Simulations, iteration took 0.58, total -61447.04, mem 1.2G
# Simulations, iteration took 0.57, total -61446.47, mem 1.22G
# Simulations, creation took 0.69, total -61445.78, mem 1.31G
# Simulations, iteration took 1.84, total -61443.94, mem 1.25G
# Simulations, iteration took 1.3, total -61442.63, mem 1.25G
# Simulations, iteration took 1.19, total -61441.44, mem 1.25G
# Simulations, iteration took 1.23, total -61440.21, mem 1.25G
# Simulations, iteration took 1.04, total -61439.18, mem 1.25G
# Simulations, iteration took 0.92, total -61438.26, mem 1.26G
# Simulations, iteration took 0.99, total -61437.27, mem 1.26G
# Simulations, iteration took 1.05, total -61436.22, mem 1.27G
# Simulations, iteration took 0.76, total -61435.46, mem 1.27G
# Simulations, iteration took 0.81, total -61434.65, mem 1.28G
# Simulations, iteration took 0.84, total -61433.81, mem 1.3G
# Simulations, iteration took 0.79, total -61433.02, mem 1.3G
# Simulations, iteration took 0.59, total -61432.42, mem 1.3G
# Simulations, iteration took 0.62, total -61431.81, mem 1.31G
# Simulations, iteration took 0.58, total -61431.22, mem 1.31G
# Simulations, iteration took 0.67, total -61430.55, mem 1.32G
# Simulations, iteration took 0.61, total -61429.94, mem 1.33G
# Simulations, iteration took 0.77, total -61429.17, mem 1.33G
# Simulations, iteration took 0.62, total -61428.55, mem 1.34G
# Simulations, iteration took 0.68, total -61427.86, mem 1.34G
# Simulations, iteration took 0.9, total -61426.95, mem 1.35G
# Simulations, iteration took 0.66, total -61426.29, mem 1.35G
# Simulations, iteration took 0.63, total -61425.64, mem 1.36G
# Simulations, iteration took 0.69, total -61424.95, mem 1.36G
# Simulations, iteration took 0.55, total -61424.4, mem 1.37G
# Simulations, iteration took 0.71, total -61423.69, mem 1.37G
# Simulations, iteration took 0.67, total -61423.02, mem 1.38G
# Simulations, iteration took 0.74, total -61422.26, mem 1.38G
# Simulations, iteration took 0.53, total -61421.74, mem 1.38G
# Simulations, iteration took 0.53, total -61421.2, mem 1.38G
# Simulations, iteration took 0.67, total -61420.53, mem 1.39G
# Simulations, iteration took 0.58, total -61419.96, mem 1.39G
# Simulations, iteration took 0.63, total -61419.33, mem 1.39G
# Simulations, iteration took 0.56, total -61418.77, mem 1.39G
# Simulations, iteration took 0.55, total -61418.22, mem 1.4G
# Simulations, iteration took 0.51, total -61417.71, mem 1.4G
# Simulations, iteration took 0.69, total -61417.01, mem 1.4G
# Simulations, iteration took 0.72, total -61416.29, mem 1.41G
# Simulations, iteration took 0.59, total -61415.7, mem 1.41G
# for desc kid at horizon 5 ever div at 40 is 0.12019826517967781
# for desc no kid at horizon 5 ever div at 40 is 0.18339529120198264
# for desc kid at horizon 6 ever div at 40 is 0.1320109439124487
# for desc no kid at horizon 6 ever div at 40 is 0.20177838577291382
# for desc kid at horizon 7 ever div at 40 is 0.12721238938053098
# for desc no kid at horizon 7 ever div at 40 is 0.19358407079646017
# for desc kid at horizon 8 ever div at 40 is 0.12396694214876033
# for desc no kid at horizon 8 ever div at 40 is 0.191541079241614
# for desc kid at horizon 9 ever div at 40 is 0.124724548259145
# for desc no kid at horizon 9 ever div at 40 is 0.19303657999118554
# for desc kid at horizon 10 ever div at 40 is 0.12068248023304202
# for desc no kid at horizon 10 ever div at 40 is 0.1856013316687474
# for desc kid at horizon 11 ever div at 40 is 0.11895321173671689
# for desc no kid at horizon 11 ever div at 40 is 0.18754956383822363
# for desc kid at horizon 12 ever div at 40 is 0.11415349016583108
# for desc no kid at horizon 12 ever div at 40 is 0.18549942151947552

# %%
# part 7.1 doubling social stigma

# table


import numpy as np
from matplotlib import pyplot as plt

diff = False


sm_25 = r'\textit{...at 25} '
sm_35 = r'\textit{...at 35} '

em_25 = r'\textit{...at 25} '
em_35 = r'\textit{...at 35} '


ed_30= r'\textit{...at 30} '
ed_40 = r'\textit{...at 40} '

dk_5= r'\textit{...5 years after} '
dk_10 = r'\textit{...10 years after} '


wk_25 = r'\textit{...at 25} '
wk_35 = r'\textit{...at 35} '

ck_md = r'\textit{child ever born, median} '
ck_30 = r'\textit{child born at 30, median} '

a = r'\textit{\% aborted} '







for educ, name in zip(['hs','col'],['high school graduates','college graduates']):

    mom_bl = filer('{} baseline.pkl'.format(educ),0,0)
    mom_ds = filer('{} double social stigma.pkl'.format(educ),0,0)

    
    for mom in (mom_bl, mom_ds):
        
        
        sm_25 += r' & ' + '{:02.1f}'.format(100*mom['single mothers among mothers at 25'])
        sm_35 += r' & ' + '{:02.1f}'.format(100*mom['single mothers among mothers at 35'])
        
        em_25 += r' & ' + '{:02.1f}'.format(100*mom['ever married at 25'])
        em_35 += r' & ' + '{:02.1f}'.format(100*mom['ever married at 25'])
        
        ed_30 += r' & ' + '{:02.1f}'.format(100*mom['ever divorced at 30'])
        ed_40 += r' & ' + '{:02.1f}'.format(100*mom['ever divorced at 40'])
        
        dk_5 += r' & ' + '{:02.1f}'.format(100*mom['divorced by years after marriage if kids first, 5'])
        dk_10 += r' & ' + '{:02.1f}'.format(100*mom['divorced by years after marriage if kids first, 10'])
        
        wk_25 += r' & ' + '{:02.1f}'.format(100*mom['with kids at 25'])
        wk_35 += r' & ' + '{:02.1f}'.format(100*mom['with kids at 35'])
        
        ck_md += r' & ' + '{:02.1f}'.format(mom['welfare of all children born, median'])
        ck_30 += r' & ' + '{:02.1f}'.format(mom['child welfare if born at 30, median'])
        
        a += r' & ' + '{:02.1f}'.format(100*mom['unplanned pregnancies aborted'])
        
print('single mothers among mothers:')
print(sm_25)
print(sm_35)
print('ever married:')
print(sm_25)
print(sm_35)
print('ever divorced:')
print(ed_30)
print(ed_40)
print('with kids:')
print(wk_25)
print(wk_35)
print('divorced if kids first:')
print(dk_5)
print(dk_10)
print('childs consumption:')
print(ck_md)
print(ck_30)
print(a)
# Out:
# single mothers among mothers:
# \textit{...at 25}  & 58.1 & 50.6 & 30.4 & 26.2
# \textit{...at 35}  & 42.8 & 42.2 & 13.2 & 12.8
# ever married:
# \textit{...at 25}  & 58.1 & 50.6 & 30.4 & 26.2
# \textit{...at 35}  & 42.8 & 42.2 & 13.2 & 12.8
# ever divorced:
# \textit{...at 30}  & 8.0 & 11.9 & 4.4 & 5.0
# \textit{...at 40}  & 21.2 & 30.4 & 17.0 & 18.1
# with kids:
# \textit{...at 25}  & 38.5 & 48.0 & 9.0 & 9.8
# \textit{...at 35}  & 69.7 & 79.7 & 63.2 & 65.4
# divorced if kids first:
# \textit{...5 years after}  & 14.0 & 28.1 & 10.7 & 16.5
# \textit{...10 years after}  & 21.7 & 34.1 & 21.1 & 27.9
# childs consumption:
# \textit{child ever born, median}  & 20.9 & 18.9 & 59.6 & 59.0
# \textit{child born at 30, median}  & 29.7 & 26.7 & 60.4 & 59.9
# \textit{\% aborted}  & 37.3 & 14.7 & 39.9 & 30.6
